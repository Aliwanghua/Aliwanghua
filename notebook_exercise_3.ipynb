# %% [markdown]
# # Exercise 3: Add international connector

# %% [markdown]
# ## Tasks:
#
# * Add the import export lines and generators.
# * Change the import price.
# * Set the co2_emissions limit to 800,000 tonnes $CO_2$
# * Apply the limit on Northern Coal Generation.
# * Add custom constraint to ensure that imports >= exports.

# %%
lesson_number = 3
print(f'Exercise {lesson_number}')
# Out:
# Exercise 3

# %%
#@title Connect to Google Drive {display-mode:"form"}
CONNECT_TO_DRIVE = True #@param {type:"boolean"}

import os
if 'lesson_number' not in locals(): lesson_number = 4

if CONNECT_TO_DRIVE:
    from google.colab import drive
    # Mount Google Drive
    drive.mount('/content/drive')

    # Define the desired working directory path
    working_dir = f'/content/drive/MyDrive/energylab-emw-2026'
    lesson_folder = f'exercise-{lesson_number}'
    lesson_dir = os.path.join(working_dir, lesson_folder)

    # Create the working directory if it doesn't exist
    if not os.path.exists(working_dir):
        os.makedirs(working_dir)
        print(f"Directory '{working_dir}' created.")
    else:
        print(f"Directory '{working_dir}' already exists.")

    # Create the lesson directory if it doesn't exist
    if not os.path.exists(lesson_dir):
        os.makedirs(lesson_dir)
        print(f"Directory '{lesson_dir}' created.")
    else:
        print(f"Directory '{lesson_dir}' already exists.")

    # Change the current working directory to the lesson directory
    os.chdir(lesson_dir)

    print(f"Current working directory: {os.getcwd()}")
else:
    print("Not connecting to Google Drive.")
# Out:
# Mounted at /content/drive
# Directory '/content/drive/MyDrive/energylab-emw-2026' already exists.
# Directory '/content/drive/MyDrive/energylab-emw-2026/exercise-3' created.
# Current working directory: /content/drive/MyDrive/energylab-emw-2026/exercise-3

# %%
#@title Install Packages {display-mode:"form"}
INSTALL_PACKAGES = True #@param {type:"boolean"}

import os

# Check if packages have already been installed in this session to prevent re-installation
if INSTALL_PACKAGES and not os.environ.get('PYPSA_PACKAGES_INSTALLED'):
  # !pip install pypsa
  # !pip install pypsa[excel]
  # !pip install folium mapclassify cartopy
  os.environ['PYPSA_PACKAGES_INSTALLED'] = 'true'
elif not INSTALL_PACKAGES:
  print("Skipping package installation.")
else:
  print("PyPSA packages are already installed for this session.")
# Out:
# Collecting pypsa
#   Downloading pypsa-1.2.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pypsa) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pypsa) (1.16.3)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from pypsa) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pypsa) (2025.12.0)
# Collecting netcdf4 (from pypsa)
#   Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting linopy>=0.7.0 (from pypsa)
#   Downloading linopy-0.8.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pypsa) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from pypsa) (5.24.1)
# Collecting pydeck>=0.6 (from pypsa)
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from pypsa) (0.13.2)
# Requirement already satisfied: geopandas>=0.9 in /usr/local/lib/python3.12/dist-packages (from pypsa) (1.1.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from pypsa) (2.1.2)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.12/dist-packages (from pypsa) (3.6.1)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.12/dist-packages (from pypsa) (2.1.0)
# Collecting validators (from pypsa)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: highspy in /usr/local/lib/python3.12/dist-packages (from pypsa) (1.14.0)
# Collecting levenshtein>=0.27.1 (from pypsa)
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from pypsa) (4.10.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa) (3.7.2)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from levenshtein>=0.27.1->pypsa)
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (1.4.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (0.12.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (2.14.1)
# Requirement already satisfied: dask>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (2026.6.0)
# Requirement already satisfied: polars>=1.31.1 in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (1.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa) (2026.2)
# Requirement already satisfied: jinja2>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pydeck>=0.6->pypsa) (3.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa) (3.3.2)
# Collecting cftime (from netcdf4->pypsa)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4->pypsa) (2026.6.17)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->pypsa) (9.1.4)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa) (8.4.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa) (6.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.1->pydeck>=0.6->pypsa) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=1.31.1->linopy>=0.7.0->pypsa) (1.35.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->pypsa) (1.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=0.18.0->linopy>=0.7.0->pypsa) (1.0.0)
# Downloading pypsa-1.2.4-py3-none-any.whl (369 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.0/369.0 kB 7.7 MB/s eta 0:00:00
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 12.2 MB/s eta 0:00:00
# Downloading linopy-0.8.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.6/184.6 kB 13.5 MB/s eta 0:00:00
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 72.0 MB/s eta 0:00:00
# Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 78.9 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.9 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.7 MB/s eta 0:00:00
# Installing collected packages: validators, rapidfuzz, cftime, pydeck, netcdf4, levenshtein, linopy, pypsa
# Successfully installed cftime-1.6.5 levenshtein-0.27.3 linopy-0.8.0 netcdf4-1.7.4 pydeck-0.9.3 pypsa-1.2.4 rapidfuzz-3.14.5 validators-0.35.0
# Requirement already satisfied: pypsa[excel] in /usr/local/lib/python3.12/dist-packages (1.2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (1.16.3)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (2025.12.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (1.7.4)
# Requirement already satisfied: linopy>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (0.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (5.24.1)
# Requirement already satisfied: pydeck>=0.6 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (0.9.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (0.13.2)
# Requirement already satisfied: geopandas>=0.9 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (1.1.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (2.1.2)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (3.6.1)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (2.1.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (0.35.0)
# Requirement already satisfied: highspy in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (1.14.0)
# Requirement already satisfied: levenshtein>=0.27.1 in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (0.27.3)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (4.10.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from pypsa[excel]) (3.1.5)
# Collecting python-calamine (from pypsa[excel])
#   Downloading python_calamine-0.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa[excel]) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa[excel]) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pypsa[excel]) (3.7.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from levenshtein>=0.27.1->pypsa[excel]) (3.14.5)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (1.4.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (0.12.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (2.14.1)
# Requirement already satisfied: dask>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (2026.6.0)
# Requirement already satisfied: polars>=1.31.1 in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (1.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from linopy>=0.7.0->pypsa[excel]) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa[excel]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa[excel]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pypsa[excel]) (2026.2)
# Requirement already satisfied: jinja2>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pydeck>=0.6->pypsa[excel]) (3.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pypsa[excel]) (3.3.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netcdf4->pypsa[excel]) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4->pypsa[excel]) (2026.6.17)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->pypsa[excel]) (2.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->pypsa[excel]) (9.1.4)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (8.4.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (6.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.1->pydeck>=0.6->pypsa[excel]) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=1.31.1->linopy>=0.7.0->pypsa[excel]) (1.35.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->pypsa[excel]) (1.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=0.18.0->linopy>=0.7.0->pypsa[excel]) (1.0.0)
# Downloading python_calamine-0.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.2/920.2 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: python-calamine
# Successfully installed python-calamine-0.8.2
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Collecting cartopy
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2026.3.0)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (3.6.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.16.3)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (26.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.1.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2026.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2026.6.17)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 75.2 MB/s eta 0:00:00
# Installing collected packages: cartopy
# Successfully installed cartopy-0.25.0

# %%
#@title Download the file for this notebook {display-mode:"form"}
DOWNLOAD_FILE = True #@param {type:"boolean"}

import urllib.request
import os

if DOWNLOAD_FILE:
    url = "https://raw.githubusercontent.com/PriyeshGosai/energylab-emw-2026/main/exercise_3.xlsx"
    file_name = url.split('/')[-1]  # Extract filename from URL
    filename= file_name
    urllib.request.urlretrieve(url, filename)
    print(f"File downloaded successfully: {os.path.abspath(filename)}")

else:
    print("Skipping file download.")
# Out:
# File downloaded successfully: /content/drive/MyDrive/energylab-emw-2026/exercise-3/exercise_3.xlsx

# %% [markdown]
# ## Custom Functions

# %%
def calculate_generator_co2(n):
    """
    Calculate total and per-generator CO2 emissions from actual power output.

    Parameters
    ----------
    n : pypsa.Network
        The network object

    Returns
    -------
    total_co2 : float
        Total CO2 emissions in tonnes
    df_co2 : pd.DataFrame
        DataFrame with CO2 per generator including efficiency, emissions factor, and p_nom
    """
    import pandas as pd

    gen_power = n.generators.dynamic.p  # Power output over time
    gen_co2_by_generator = {}

    for gen_name in gen_power.columns:
        carrier = n.generators.static.loc[gen_name, 'carrier']
        co2_rate = n.carriers.static.loc[carrier, 'co2_emissions']
        efficiency = n.generators.static.loc[gen_name, 'efficiency']
        p_nom = n.generators.static.loc[gen_name, 'p_nom']

        # Sum actual power output and multiply by CO2 rate, adjusted for efficiency
        gen_co2 = gen_power[gen_name].sum() * co2_rate / efficiency

        gen_co2_by_generator[gen_name] = {
            'co2_emissions': gen_co2,
            'efficiency': efficiency,
            'emissions_factor': co2_rate,
            'p_nom': p_nom
        }

    # Convert to DataFrame
    df_co2 = pd.DataFrame(gen_co2_by_generator).T
    df_co2 = df_co2.sort_values('co2_emissions', ascending=False)

    total_co2 = df_co2['co2_emissions'].sum()

    return total_co2, df_co2

# %% [markdown]
# ## Model

# %%
import pypsa
pypsa.options.api.new_components_api = True

import pandas as pd
pd.options.plotting.backend = 'plotly'

n = pypsa.Network('exercise_3_completed.xlsx')

n.storage_units.static['overnight_cost']
# Out:
# WARNING:pypsa._options:Unknown option 'packages_installed' from env var 'PYPSA_PACKAGES_INSTALLED'. Use pypsa.options.describe() to see valid options.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2590/2159742343.py in <cell line: 0>()
#       5 pd.options.plotting.backend = 'plotly'
#       6
# ----> 7 n = pypsa.Network('exercise_3_completed.xlsx')
#       8
#       9 n.storage_units.static['overnight_cost']
#
# /usr/local/lib/python3.12/dist-packages/pypsa/networks.py in __init__(self, import_name, name, ignore_standard_types, **kwargs)
#     197                 self.import_from_netcdf(import_name)
#     198             elif str(import_name).endswith((".xls", ".xlsx", ".xlsm", ".xlsb")):
# --> 199                 self.import_from_excel(import_name)
#     200             elif isinstance(import_name, Path) and import_name.is_dir():
#     201                 self.import_from_csv_folder(import_name)
#
# /usr/local/lib/python3.12/dist-packages/pypsa/network/io.py in import_from_excel(self, path, skip_time, engine)
#    1573         """
#    1574         basename = Path(path).stem
# -> 1575         with _ImporterExcel(path, engine=engine) as importer:
#    1576             self._import_from_importer(importer, basename=basename, skip_time=skip_time)
#    1577
#
# /usr/local/lib/python3.12/dist-packages/pypsa/network/io.py in __init__(self, path, engine)
#     460         if not path.is_file():
#     461             msg = f"Excel file {path} does not exist."
# --> 462             raise FileNotFoundError(msg)
#     463         self.engine = engine
#     464
#
# FileNotFoundError: Excel file exercise_3_completed.xlsx does not exist.

# %%
n.sanitize()
# n.optimize()

n.optimize.create_model()

export_gen = n.model.variables["Generator-p"].loc[:, "Thailand Export"]
import_gen = n.model.variables["Generator-p"].loc[:, "Thailand Import"]

n.model.add_constraints(
    export_gen <= import_gen,
    name="Thailand_Export_le_Import"
)

n.optimize.solve_model()

# %%
total_co2, df_co2 = calculate_generator_co2(n)

# %%
total_co2

# %%
df_co2_coal = df_co2[df_co2.index.str.contains("Coal")]

df_co2_coal['co2_emissions'].plot.bar()

# %% [markdown]
# ## Results

# %%
n.generators.static.p_nom_opt.plot.barh()

# %%
n.storage_units.static.p_nom_opt.plot.barh()

# %%
s = n.statistics

df = s.curtailment(groupby = False, groupby_time = False, carrier = ['solar','wind']).T

df.columns = df.columns.get_level_values("name")

df.plot()

# %%
s.curtailment(groupby = False, carrier = ['solar','wind'])

# %%
n.generators.dynamic.p.plot.area(stacked = True)

# %%
n.storage_units.dynamic.state_of_charge.plot(title="Battery State of Charge",
                                            labels={
                                                "value": "State of Charge (MWh)",
                                                "index": "Time"
                                            })

# %%
import pandas as pd

p_dispatch = n.storage_units.dynamic.p_dispatch.copy()
p_store = (n.storage_units.dynamic.p_store*-1).copy()

# prefix column names to distinguish storage dispatch/store from generators
p_dispatch.columns = "Discharge " + p_dispatch.columns
p_store.columns = "Store " + p_store.columns

p_all = pd.concat(
    [p_store, n.generators.dynamic.p, p_dispatch],
    axis=1
)

p_all.plot.area()

# %%
n_example = pypsa.examples.ac_dc_meshed()

# %%
n_example.global_constraints.static
